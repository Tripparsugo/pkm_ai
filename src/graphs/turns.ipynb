# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
from anchor import TMP_DIR

df = pd.read_csv(f"{TMP_DIR}/turns.csv")
df
# Out:
#     StateValue  Reward                                              Order  \
# 0         0.00    0.00                             hypnosis (Move object)
# 1         0.00    0.00  exploud (pokemon object) [Active: False, Statu...
# 2         0.00   -0.43  hippowdon (pokemon object) [Active: False, Sta...
# 3         0.00    0.43                            boomburst (Move object)
# 4        -0.43   -0.18                            stoneedge (Move object)
# ..         ...     ...                                                ...
# 67        3.14    0.00  guzzlord (pokemon object) [Active: True, Statu...
# 68       -4.03   -0.01  clawitzer (pokemon object) [Active: False, Sta...
# 69        3.14   -0.18                           sludgebomb (Move object)
# 70       -4.04   -0.25  victini (pokemon object) [Active: True, Status...
# 71        2.96     NaN                                                NaN
#
#    Username  TurnN
# 0   usernA0      0
# 1    userB0      0
# ...

# %%
p = sns.lineplot(data=df, x="TurnN", y="StateValue", hue="Username")
